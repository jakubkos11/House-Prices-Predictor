# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
train_data = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
train_data = apply_feature_engineering(train_data)

# 1. Distribution of house prices
plt.figure(figsize = (10,5))
sns.histplot(train_data['SalePrice'], bins = 50, kde = True)
plt.title('Distribution of House Prices')
plt.xlabel('SalePrice')
plt.ylabel('Number of Houses')
plt.show()

# Log-transformed distribution (often better for modeling)
plt.figure(figsize = (10,5))
sns.histplot(np.log1p(train_data['SalePrice']), bins = 50, kde = True, color = 'orange')
plt.title('Log-Transformed Distribution of House Prices')
plt.xlabel('log1p(SalePrice)')
plt.ylabel('Number of Houses')
plt.show()

# 3. Scatter plots for top correlated features with SalePrice
top_corr_features = corr['SalePrice'].abs().sort_values(ascending = False).index[1:6]
for feature in top_corr_features:
    plt.figure(figsize = (8,5))
    sns.scatterplot(x = train_data[feature], y = train_data['SalePrice'])
    plt.title(f'{feature} vs SalePrice')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# 4. Boxplots for selected categorical features
cat_features = ['OverallQual', 'ExterQual', 'KitchenQual', 'GarageCars', 'Fireplaces']
for feature in cat_features:
    plt.figure(figsize = (8,5))
    sns.boxplot(x=train_data[feature], y = train_data['SalePrice'])
    plt.title(f'{feature} vs SalePrice')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# 5. Scatter plots for engineered features
engineered_features = ['HouseAge', 'RemodAge', 'TotalSF', 'TotalBath', 'TotalRooms', 'GarageAreaPerCar', 'LotAreaPerSurface', 'OverallScore']
for feature in engineered_features:
    plt.figure(figsize = (8,5))
    sns.scatterplot(x = train_data[feature], y = train_data['SalePrice'])
    plt.title(f'{feature} vs SalePrice')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# 6. Heatmap for engineered features correlations
corr_eng = train_data[engineered_features + ['SalePrice']].corr()
plt.figure(figsize = (10,8))
sns.heatmap(corr_eng, annot = True, fmt = ".2f", cmap = 'viridis')
plt.title('Correlation of Engineered Features with SalePrice')
plt.show()
